# %% [markdown]
# Not saving the results any where.
# TODO: save somewhere if needed

# %%
# importing pandas as pd
import pandas as pd
import os

# %%
# array contains all the flowResult files which belongs to this MUD flow  
# DUP data/flowResults/V5/AwairAirQuality
all_files = ['AwairAirQuality/AwairAirQuality_70886b100fc6.pcap_flowResult.csv', 
             'LiFXBulb/LiFXBulb_d073d5018308.pcap_flowResult.csv',
             'PixStarPhotoFrame/PixStarPhotoFrame_e076d033bb85.pcap_flowResult.csv',  
             'RingDoorBell/RingDoorBell_884aea31669d.pcap_flowResult.csv',  
             'TPLinkCamera/TPLinkCamera_f4f26D9351f1.pcap_flowResult.csv', 
             'TribySpeaker/TribySpeaker_18B79E022044.pcap_flowResult.csv', 
             'AmazonEcho/DUP_CONCATANATED_AmazonEcho_44650d56ccd3_flowResult.csv', 
             'WithingsSleepSensor/DUP_CONCATANATED_WithingsSleepSensor_0024e42028c6_flowResult.csv',
             'SamsungCamera/DUP_CONCATANATED_SamsungCamera_00166cab6b88_flowResult.csv',
             'WithingsBabyMonitor/WithingsBabyMonitor_0024e41118a8.pcapng_flowResult.csv'
             ]

# %%
# paths of other files
# path = ""
path = "../../../../data/flowResults/V5"

# %%
# loading all the files as pandas dataframes
# all_dfs = {<file name>: df}
all_dfs = {}

for filename in all_files:
    print(f'filename: {filename}')
    df = pd.read_csv(os.path.join(path, filename))
    print(type(df[' ipProto']))
    all_dfs[filename] = df
# Out:
# filename: AwairAirQuality/AwairAirQuality_70886b100fc6.pcap_flowResult.csv
# <class 'pandas.core.series.Series'>
# filename: LiFXBulb/LiFXBulb_d073d5018308.pcap_flowResult.csv
# <class 'pandas.core.series.Series'>
# filename: PixStarPhotoFrame/PixStarPhotoFrame_e076d033bb85.pcap_flowResult.csv
# <class 'pandas.core.series.Series'>
# filename: RingDoorBell/RingDoorBell_884aea31669d.pcap_flowResult.csv
# <class 'pandas.core.series.Series'>
# filename: TPLinkCamera/TPLinkCamera_f4f26D9351f1.pcap_flowResult.csv
# <class 'pandas.core.series.Series'>
# filename: TribySpeaker/TribySpeaker_18B79E022044.pcap_flowResult.csv
# <class 'pandas.core.series.Series'>
# filename: AmazonEcho/DUP_CONCATANATED_AmazonEcho_44650d56ccd3_flowResult.csv
# <class 'pandas.core.series.Series'>
# filename: WithingsSleepSensor/DUP_CONCATANATED_WithingsSleepSensor_0024e42028c6_flowResult.csv
# <class 'pandas.core.series.Series'>
# filename: SamsungCamera/DUP_CONCATANATED_SamsungCamera_00166cab6b88_flowResult.csv
# <class 'pandas.core.series.Series'>
# filename: WithingsBabyMonitor/WithingsBabyMonitor_0024e41118a8.pcapng_flowResult.csv
# <class 'pandas.core.series.Series'>

# %%
for _, df in all_dfs.items():
    df.info()

# df.columns

# print(df[' ipProto'].str.contains('6'))
# print(df[' ipProto']==6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2153 entries, 0 to 2152
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   srcMac                 0 non-null      float64
#  1    dstMac                0 non-null      float64
#  2    ethType               2153 non-null   object
#  3    srcIp                 2153 non-null   object
#  4    dstIp                 2153 non-null   object
#  5    ipProto               2153 non-null   int64
#  6    srcPort               2153 non-null   object
#  7    dstPort               2153 non-null   object
#  8    protocol              2153 non-null   object
#  9    allMatches            2153 non-null   object
#  10   numPayloadOnePackets  2153 non-null   int64
#  11   numPayloadTwoPackets  2153 non-null   int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 202.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7740 entries, 0 to 7739
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   srcMac                 0 non-null      float64
#  1    dstMac                0 non-null      float64
#  2    ethType               7740 non-null   object
#  3    srcIp                 7740 non-null   object
#  4    dstIp                 7740 non-null   object
#  5    ipProto               7740 non-null   int64
#  6    srcPort               7740 non-null   object
#  7    dstPort               7740 non-null   object
#  8    protocol              7740 non-null   object
#  9    allMatches            7740 non-null   object
#  10   numPayloadOnePackets  7740 non-null   int64
#  11   numPayloadTwoPackets  7740 non-null   int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 725.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6239 entries, 0 to 6238
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   srcMac                 0 non-null      float64
#  1    dstMac                0 non-null      float64
#  2    ethType               6239 non-null   object
#  3    srcIp                 6239 non-null   object
#  4    dstIp                 6239 non-null   object
#  5    ipProto               6239 non-null   int64
#  6    srcPort               6239 non-null   object
#  7    dstPort               6239 non-null   object
#  8    protocol              6239 non-null   object
#  9    allMatches            6239 non-null   object
#  10   numPayloadOnePackets  6239 non-null   int64
#  11   numPayloadTwoPackets  6239 non-null   int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 585.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   srcMac                 0 non-null      float64
#  1    dstMac                0 non-null      float64
#  2    ethType               633 non-null    object
#  3    srcIp                 633 non-null    object
#  4    dstIp                 633 non-null    object
#  5    ipProto               633 non-null    int64
#  6    srcPort               633 non-null    object
#  7    dstPort               633 non-null    object
#  8    protocol              633 non-null    object
#  9    allMatches            633 non-null    object
#  10   numPayloadOnePackets  633 non-null    int64
#  11   numPayloadTwoPackets  633 non-null    int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 59.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10549 entries, 0 to 10548
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   srcMac                 0 non-null      float64
#  1    dstMac                0 non-null      float64
#  2    ethType               10549 non-null  object
#  3    srcIp                 10549 non-null  object
#  4    dstIp                 10549 non-null  object
#  5    ipProto               10549 non-null  int64
#  6    srcPort               10549 non-null  object
#  7    dstPort               10549 non-null  object
#  8    protocol              10549 non-null  object
#  9    allMatches            10549 non-null  object
#  10   numPayloadOnePackets  10549 non-null  int64
#  11   numPayloadTwoPackets  10549 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 989.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7953 entries, 0 to 7952
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   srcMac                 0 non-null      float64
#  1    dstMac                0 non-null      float64
#  2    ethType               7953 non-null   object
#  3    srcIp                 7953 non-null   object
#  4    dstIp                 7953 non-null   object
#  5    ipProto               7953 non-null   int64
#  6    srcPort               7953 non-null   object
#  7    dstPort               7953 non-null   object
#  8    protocol              7953 non-null   object
#  9    allMatches            7953 non-null   object
#  10   numPayloadOnePackets  7953 non-null   int64
#  11   numPayloadTwoPackets  7953 non-null   int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 745.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106964 entries, 0 to 106963
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   srcMac                 0 non-null       float64
#  1    dstMac                0 non-null       float64
#  2    ethType               106964 non-null  object
#  3    srcIp                 106964 non-null  object
#  4    dstIp                 106964 non-null  object
#  5    ipProto               106964 non-null  int64
#  6    srcPort               106964 non-null  object
#  7    dstPort               106964 non-null  object
#  8    protocol              106964 non-null  object
#  9    allMatches            106964 non-null  object
#  10   numPayloadOnePackets  106964 non-null  int64
#  11   numPayloadTwoPackets  106964 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 9.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38899 entries, 0 to 38898
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   srcMac                 0 non-null      float64
#  1    dstMac                0 non-null      float64
#  2    ethType               38899 non-null  object
#  3    srcIp                 38899 non-null  object
#  4    dstIp                 38899 non-null  object
#  5    ipProto               38899 non-null  int64
#  6    srcPort               38899 non-null  object
#  7    dstPort               38899 non-null  object
#  8    protocol              38899 non-null  object
#  9    allMatches            38899 non-null  object
#  10   numPayloadOnePackets  38899 non-null  int64
#  11   numPayloadTwoPackets  38899 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 3.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56478 entries, 0 to 56477
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   srcMac                 0 non-null      float64
#  1    dstMac                0 non-null      float64
#  2    ethType               56478 non-null  object
#  3    srcIp                 56478 non-null  object
#  4    dstIp                 56478 non-null  object
#  5    ipProto               56478 non-null  int64
#  6    srcPort               56478 non-null  object
#  7    dstPort               56478 non-null  object
#  8    protocol              56478 non-null  object
#  9    allMatches            56478 non-null  object
#  10   numPayloadOnePackets  56478 non-null  int64
#  11   numPayloadTwoPackets  56478 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 5.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10114 entries, 0 to 10113
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   srcMac                 0 non-null      float64
#  1    dstMac                0 non-null      float64
#  2    ethType               10114 non-null  object
#  3    srcIp                 10114 non-null  object
#  4    dstIp                 10114 non-null  object
#  5    ipProto               10114 non-null  int64
#  6    srcPort               10114 non-null  object
#  7    dstPort               10114 non-null  object
#  8    protocol              10114 non-null  object
#  9    allMatches            10114 non-null  object
#  10   numPayloadOnePackets  10114 non-null  int64
#  11   numPayloadTwoPackets  10114 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 948.3+ KB

# %%
total = 0
for i in all_files:
    print('Number of flows in {0}: {1}'.format(i, len(all_dfs[i])))
    # total += len(df)
print("Total number of flows:", total)
# Out:
# Number of flows in AwairAirQuality/AwairAirQuality_70886b100fc6.pcap_flowResult.csv: 2153
# Number of flows in LiFXBulb/LiFXBulb_d073d5018308.pcap_flowResult.csv: 7740
# Number of flows in PixStarPhotoFrame/PixStarPhotoFrame_e076d033bb85.pcap_flowResult.csv: 6239
# Number of flows in RingDoorBell/RingDoorBell_884aea31669d.pcap_flowResult.csv: 633
# Number of flows in TPLinkCamera/TPLinkCamera_f4f26D9351f1.pcap_flowResult.csv: 10549
# Number of flows in TribySpeaker/TribySpeaker_18B79E022044.pcap_flowResult.csv: 7953
# Number of flows in AmazonEcho/DUP_CONCATANATED_AmazonEcho_44650d56ccd3_flowResult.csv: 106964
# Number of flows in WithingsSleepSensor/DUP_CONCATANATED_WithingsSleepSensor_0024e42028c6_flowResult.csv: 38899
# Number of flows in SamsungCamera/DUP_CONCATANATED_SamsungCamera_00166cab6b88_flowResult.csv: 56478
# Number of flows in WithingsBabyMonitor/WithingsBabyMonitor_0024e41118a8.pcapng_flowResult.csv: 10114
# Total number of flows: 0

# %%
# columns
'''
    Index(['srcMac', ' dstMac', ' ethType', ' srcIp', ' dstIp', ' ipProto',
        ' srcPort', ' dstPort', ' protocol', ' allMatches',
        ' numPayloadOnePackets', ' numPayloadTwoPackets'],
        dtype='object')
'''
ipProto = 'UDP'

if ipProto == 'TCP':
    ipProtoNum = 6
elif ipProto == 'UDP':
    ipProtoNum = 17

stdPort = '1900'
protoName = 'ssdp'
for filename, df in all_dfs.items():
    # getting the flows for this MUD flow
    # print(df[' ipProto'])
    # MUD_df = df.loc[df[' ipProto'].str.contains('6') & ((df[' srcPort']=='443') | (df[' dstPort']=='443'))]  #
    MUD_df_1 = df.loc[(df[' ipProto'] == ipProtoNum) & ((df[' srcPort']==stdPort) | (df[' dstPort']==stdPort)) & (df[' protocol'].str.contains(protoName))]  #
    MUD_df_2 = df.loc[(df[' protocol'].str.contains(protoName))]  #
    MUD_df_3 = df  #
    print(filename)
    print(f'{ipProto}/{stdPort} {protoName}:#######################')
    print(MUD_df_1.groupby(' protocol')[' protocol'].count().reset_index(name='No. of flows'))
    print(f'Total {protoName}:#######################')
    print(MUD_df_2.groupby(' protocol')[' protocol'].count().reset_index(name='No. of flows'))
    print(f'Total flows:#######################')
    print(f'\t\t     {len(MUD_df_3)}')
    print()
    print('\n')
    # break
# Out:
# AwairAirQuality/AwairAirQuality_70886b100fc6.pcap_flowResult.csv
# UDP/1900 ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total flows:#######################
# 		     2153
#
#
#
# LiFXBulb/LiFXBulb_d073d5018308.pcap_flowResult.csv
# UDP/1900 ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total flows:#######################
# 		     7740
#
#
#
# PixStarPhotoFrame/PixStarPhotoFrame_e076d033bb85.pcap_flowResult.csv
# UDP/1900 ssdp:#######################
#    protocol  No. of flows
# 0      ssdp             2
# Total ssdp:#######################
#    protocol  No. of flows
# 0      ssdp             2
# Total flows:#######################
# 		     6239
#
#
#
# RingDoorBell/RingDoorBell_884aea31669d.pcap_flowResult.csv
# UDP/1900 ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total flows:#######################
# 		     633
#
#
#
# TPLinkCamera/TPLinkCamera_f4f26D9351f1.pcap_flowResult.csv
# UDP/1900 ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total flows:#######################
# 		     10549
#
#
#
# TribySpeaker/TribySpeaker_18B79E022044.pcap_flowResult.csv
# UDP/1900 ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total flows:#######################
# 		     7953
#
#
#
# AmazonEcho/DUP_CONCATANATED_AmazonEcho_44650d56ccd3_flowResult.csv
# UDP/1900 ssdp:#######################
#    protocol  No. of flows
# 0      ssdp            15
# Total ssdp:#######################
#    protocol  No. of flows
# 0      ssdp           308
# Total flows:#######################
# 		     106964
#
#
#
# WithingsSleepSensor/DUP_CONCATANATED_WithingsSleepSensor_0024e42028c6_flowResult.csv
# UDP/1900 ssdp:#######################
#    protocol  No. of flows
# 0      ssdp             1
# Total ssdp:#######################
#    protocol  No. of flows
# 0      ssdp             1
# Total flows:#######################
# 		     38899
#
#
#
# SamsungCamera/DUP_CONCATANATED_SamsungCamera_00166cab6b88_flowResult.csv
# UDP/1900 ssdp:#######################
#    protocol  No. of flows
# 0      ssdp           687
# Total ssdp:#######################
#    protocol  No. of flows
# 0      ssdp           687
# Total flows:#######################
# 		     56478
#
#
#
# WithingsBabyMonitor/WithingsBabyMonitor_0024e41118a8.pcapng_flowResult.csv
# UDP/1900 ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total ssdp:#######################
# Empty DataFrame
# Columns: [ protocol, No. of flows]
# Index: []
# Total flows:#######################
# 		     10114

# %%
# checking what the non standard ports are

# columns
'''
    Index(['srcMac', ' dstMac', ' ethType', ' srcIp', ' dstIp', ' ipProto',
        ' srcPort', ' dstPort', ' protocol', ' allMatches',
        ' numPayloadOnePackets', ' numPayloadTwoPackets'],
        dtype='object')
'''

device_non_standard_flows = {}
for filename, df in all_dfs.items():
    # getting the flows for this MUD flow
    # print(df[' ipProto'])
    # MUD_df = df.loc[df[' ipProto'].str.contains('6') & ((df[' srcPort']=='443') | (df[' dstPort']=='443'))]  #
    MUD_df_21 = df.loc[(df[' ipProto'] == ipProtoNum) & ((df[' srcPort']!=stdPort) & (df[' dstPort']!=stdPort)) & (df[' protocol'].str.contains(protoName))]  #
    MUD_df_22 = df.loc[(df[' protocol'].str.contains(protoName))]  #
    MUD_df_23 = df#

    unique_ports_using_attribute = {} 
    for index in MUD_df_21.index:  # per line in the df
        
        srcP = str(df[' srcPort'][index])
        dstP = str(df[' dstPort'][index])
        # value_flow = df[' srcIp'][index] + '-' + df[' dstIp'][index] + '-' + str(df[' ipProto'][index]) + '-' + str(df[' srcPort'][index]) + '-' + str(df[' dstPort'][index])
        
        if srcP not in unique_ports_using_attribute:  # adding unique flow with a violation
            unique_ports_using_attribute[srcP] = 0
        if dstP not in unique_ports_using_attribute:  # adding unique flow with a violation
            unique_ports_using_attribute[dstP] = 0

        unique_ports_using_attribute[srcP] += 1
        unique_ports_using_attribute[dstP] += 1

    unique_ports_using_attribute = dict(sorted(unique_ports_using_attribute.items(), key=lambda item: item[1], reverse=True))
    device_non_standard_flows[filename] = unique_ports_using_attribute

for key,val in device_non_standard_flows.items():
    print(f'key: {key}, val: {val}')
    # break
# Out:
# key: AwairAirQuality/AwairAirQuality_70886b100fc6.pcap_flowResult.csv, val: {}
# key: LiFXBulb/LiFXBulb_d073d5018308.pcap_flowResult.csv, val: {}
# key: PixStarPhotoFrame/PixStarPhotoFrame_e076d033bb85.pcap_flowResult.csv, val: {}
# key: RingDoorBell/RingDoorBell_884aea31669d.pcap_flowResult.csv, val: {}
# key: TPLinkCamera/TPLinkCamera_f4f26D9351f1.pcap_flowResult.csv, val: {}
# key: TribySpeaker/TribySpeaker_18B79E022044.pcap_flowResult.csv, val: {}
# key: AmazonEcho/DUP_CONCATANATED_AmazonEcho_44650d56ccd3_flowResult.csv, val: {'50000': 293, '40771': 1, '57526': 1, '56589': 1, '42559': 1, '39524': 1, '48034': 1, '51683': 1, '51422': 1, '58719': 1, '34612': 1, '57535': 1, '39668': 1, '32826': 1, '59573': 1, '45423': 1, '45556': 1, '37628': 1, '48181': 1, '35094': 1, '49000': 1, '37767': 1, '33041': 1, '33524': 1, '43655': 1, '55286': 1, '52171': 1, '41612': 1, '38542': 1, '40375': 1, '53559': 1, '48746': 1, '52374': 1, '54282': 1, '58204': 1, '38910': 1, '56433': 1, '45163': 1, '47693': 1, '42669': 1, '40398': 1, '41200': 1, '55847': 1, '41826': 1, '49481': 1, '38922': 1, '53573': 1, '49840': 1, '40013': 1, '48297': 1, '55726': 1, '45797': 1, '36181': 1, '58482': 1, '41400': 1, '57963': 1, '37695': 1, '58679': 1, '45105': 1, '52814': 1, '54370': 1, '57224': 1, '40701': 1, '38162': 1, '54105': 1, '49073': 1, '56786': 1, '59150': 1, '41908': 1, '60014': 1, '54606': 1, '59504': 1, '44542': 1, '39370': 1, '43341': 1, '52961': 1, '56174': 1, '47799': 1, '34407': 1, '41751': 1, '51953': 1, '42204': 1, '34358': 1, '34224': 1, '32923': 1, '48915': 1, '50394': 1, '57077': 1, '48315': 1, '60814': 1, '36461': 1, '45815': 1, '58516': 1, '57444': 1, '42486': 1, '58157': 1, '54326': 1, '44131': 1, '51340': 1, '38124': 1, '50513': 1, '49525': 1, '54959': 1, '35530': 1, '40572': 1, '43555': 1, '33263': 1, '51357': 1, '40801': 1, '59104': 1, '36962': 1, '54468': 1, '59606': 1, '55554': 1, '60353': 1, '48827': 1, '60226': 1, '48822': 1, '56324': 1, '37127': 1, '43276': 1, '42913': 1, '57538': 1, '58601': 1, '36908': 1, '57797': 1, '60069': 1, '44356': 1, '43288': 1, '34606': 1, '37271': 1, '44350': 1, '43160': 1, '40665': 1, '40530': 1, '49122': 1, '47702': 1, '43033': 1, '35926': 1, '37154': 1, '58626': 1, '37159': 1, '56223': 1, '57552': 1, '52651': 1, '51588': 1, '43049': 1, '34979': 1, '52781': 1, '52718': 1, '43101': 1, '36284': 1, '46705': 1, '56683': 1, '48264': 1, '50336': 1, '55493': 1, '51539': 1, '44459': 1, '58825': 1, '60040': 1, '37378': 1, '48159': 1, '43136': 1, '36719': 1, '37083': 1, '41408': 1, '44041': 1, '48709': 1, '33491': 1, '35626': 1, '41550': 1, '59894': 1, '52598': 1, '50080': 1, '35746': 1, '46590': 1, '44064': 1, '41691': 1, '57246': 1, '57113': 1, '36884': 1, '39251': 1, '55940': 1, '43706': 1, '44904': 1, '48862': 1, '39697': 1, '59700': 1, '58893': 1, '33158': 1, '44388': 1, '58640': 1, '47603': 1, '46537': 1, '50271': 1, '34333': 1, '56253': 1, '38266': 1, '38007': 1, '59736': 1, '35785': 1, '37071': 1, '52438': 1, '53891': 1, '56935': 1, '32833': 1, '57293': 1, '46135': 1, '42438': 1, '37620': 1, '39185': 1, '35580': 1, '47212': 1, '41383': 1, '39195': 1, '44981': 1, '49615': 1, '47351': 1, '59468': 1, '39074': 1, '38713': 1, '47227': 1, '48559': 1, '53558': 1, '39398': 1, '47413': 1, '51171': 1, '58339': 1, '43980': 1, '43981': 1, '58460': 1, '40394': 1, '50807': 1, '41463': 1, '49709': 1, '48639': 1, '40271': 1, '47439': 1, '47566': 1, '56072': 1, '45173': 1, '35346': 1, '57150': 1, '34090': 1, '49410': 1, '45978': 1, '51995': 1, '38765': 1, '39704': 1, '35156': 1, '36372': 1, '55578': 1, '38773': 1, '39712': 1, '51746': 1, '43465': 1, '45993': 1, '35140': 1, '34073': 1, '39982': 1, '45733': 1, '38658': 1, '40719': 1, '37590': 1, '55465': 1, '56662': 1, '48377': 1, '38400': 1, '48380': 1, '51761': 1, '54451': 1, '51827': 1, '41136': 1, '46160': 1, '42335': 1, '54447': 1, '33636': 1, '35061': 1, '37402': 1, '38868': 1, '53258': 1, '53147': 1, '45822': 1, '51971': 1, '41165': 1, '42232': 1, '40931': 1, '40092': 1, '48203': 1, '49532': 1, '50788': 1, '47395': 1, '35033': 1}
# key: WithingsSleepSensor/DUP_CONCATANATED_WithingsSleepSensor_0024e42028c6_flowResult.csv, val: {}
# key: SamsungCamera/DUP_CONCATANATED_SamsungCamera_00166cab6b88_flowResult.csv, val: {}
# key: WithingsBabyMonitor/WithingsBabyMonitor_0024e41118a8.pcapng_flowResult.csv, val: {}
