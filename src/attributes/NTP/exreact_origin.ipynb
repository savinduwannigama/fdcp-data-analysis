# %%
# importing pandas as pd
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
import shutil

# %%
device_dir_paths = [
    'AwairAirQuality',
    'LiFXBulb',
    'PixStarPhotoFrame',
    'RingDoorBell',
    'TPLinkCamera',
    'TribySpeaker',

    # 'AmazonEcho/1',
    # 'AmazonEcho/2',
    # 'AmazonEcho/3',
    # 'AmazonEcho/4',
    # 'AmazonEcho/5',
    # 'AmazonEcho/6',
    # 'AmazonEcho/7',
    # 'AmazonEcho/8',
    # 'AmazonEcho/9',
    'AmazonEcho',

    # 'NestProtect/1',
    # 'NestProtect/2',
    # 'NestProtect/3',
    # 'NestProtect/4',
    # 'NestProtect/5',
    # 'NestProtect/6',
    # 'NestProtect/7',

    # 'WithingsSleepSensor/1',
    # 'WithingsSleepSensor/2',
    # 'WithingsSleepSensor/3',
    # 'WithingsSleepSensor/4',
    'WithingsSleepSensor',

    # 'SamsungCamera/1',
    # 'SamsungCamera/2',
    # 'SamsungCamera/3',
    # 'SamsungCamera/4',
    # 'SamsungCamera/5',
    # 'SamsungCamera/6',
    # 'SamsungCamera/7',
    # 'SamsungCamera/8',
    # 'SamsungCamera/9',
    # 'SamsungCamera/10',
    # 'SamsungCamera/11',
    # 'SamsungCamera/12',
    'SamsungCamera',

    'WithingsBabyMonitor'
]

# %%
# for RESPONSE attribute files
root_dir_path = '../../../data/attributes/V3/response_attributes'
final_output_file = '../../../results/attributes/NTP/NEW_ntp_origin_response_attributes.csv'  

##################################################################################

# for REQUEST attribute files
# root_dir_path = '../../../data/attributes/V3/request_attributes'
# final_output_file = '../../../results/attributes/NTP/NEW_ntp_origin_request_attributes.csv'  

checkedProto = 'ntp'

# %%
'''
data_device =    
    {
        device: {
            protocol: df of attributes.csv
            ...
        } ,
        ...
    }
'''

# Create an empty list to store the data from CSV files
data_device = {}

for device_dir_path in device_dir_paths:
    # this is needed because for outputs from the java script the separator is ',,,'.
    # but for devices with concatanated attribute files the separator is '/'
    if device_dir_path == 'SamsungCamera' or device_dir_path == 'AmazonEcho' or device_dir_path == 'WithingsSleepSensor':
        sepa = '|'
    else:
        sepa = ',,,'
    data_proto = {}
    print(f'device_dir_path: {device_dir_path}')
    directory_path  = os.path.join(root_dir_path, device_dir_path)
    # print(f'directory_path: {directory_path}')
    # Get a list of all files in the directory
    file_list = os.listdir(directory_path)

    # Iterate over each file in the directory
    for file_name in file_list:
        print(f'filename: {file_name}')
        # reading only the attributes files
        if 'attributes' in file_name:
            proto = file_name.split('attributes')[0]
            # Check if the file is a CSV file
            if file_name.endswith('.csv'):
                # Create the file path
                file_path = os.path.join(directory_path, file_name)
                # print(f'device_dir_path: {device_dir_path}  |  proto: {proto}')
                # Read the CSV file and append its data to the list
                try:
                    df = pd.read_csv(file_path, sep=sepa)
                    # df = pd.read_csv(file_path, sep='|')
                except pd.errors.EmptyDataError:
                    df = pd.DataFrame()  # Create an empty DataFrame 

                # data.append(df)

                data_proto[proto] = df
                # data_proto[proto] = 'df'
    
    data_device[device_dir_path] = data_proto

# # Write dictionary as JSON
# with open('output.json', 'w') as json_file:
#     json.dump(data_device, json_file)

# data_device['AwairAirQuality']['tls'][' violations']
# Out:
# device_dir_path: AwairAirQuality
# filename: tlsattributes.csv
# filename: dnsattributes.csv
# filename: dhcpattributes.csv
# filename: icmpattributes.csv
# filename: ntpattributes.csv
# device_dir_path: LiFXBulb
# filename: tlsattributes.csv
# filename: dnsattributes.csv
# filename: isakmpattributes.csv
# filename: dhcpattributes.csv
# filename: icmpattributes.csv
# filename: ntpattributes.csv
# device_dir_path: PixStarPhotoFrame
# filename: tlsattributes.csv
# filename: ssdpattributes.csv
# filename: dnsattributes.csv
# filename: dhcpattributes.csv
# filename: igmpattributes.csv
# filename: icmpattributes.csv
# filename: httpattributes.csv
# filename: smbattributes.csv
# filename: nbnsattributes.csv
# device_dir_path: RingDoorBell
# filename: tlsattributes.csv
# filename: syslogattributes.csv
# filename: dnsattributes.csv
# filename: isakmpattributes.csv
# filename: dhcpattributes.csv
# filename: rtpattributes.csv
# filename: sipattributes.csv
# filename: icmpattributes.csv
# filename: httpattributes.csv
# filename: ntpattributes.csv
# device_dir_path: TPLinkCamera
# filename: classic-stunattributes.csv
# filename: tlsattributes.csv
# filename: dnsattributes.csv
# filename: dhcpattributes.csv
# filename: igmpattributes.csv
# filename: icmpattributes.csv
# filename: mdnsattributes.csv
# filename: httpattributes.csv
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# filename: ntpattributes.csv
# device_dir_path: TribySpeaker
# filename: tlsattributes.csv
# filename: dnsattributes.csv
# filename: dhcpattributes.csv
# filename: sipattributes.csv
# filename: icmpattributes.csv
# filename: mdnsattributes.csv
# filename: httpattributes.csv
# filename: ntpattributes.csv
# device_dir_path: AmazonEcho
# filename: 5
# filename: 4
# filename: 6
# filename: concatAmazonEchoResAttr.ipynb
# filename: ssdpattributes.csv
# filename: 9
# filename: dnsattributes.csv
# filename: 2
# filename: 7
# filename: dhcpattributes.csv
# filename: 1
# filename: 8
# filename: 3
# filename: httpattributes.csv
# filename: ntpattributes.csv
# device_dir_path: WithingsSleepSensor
# filename: 4
# filename: ssdpattributes.csv
# filename: dnsattributes.csv
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# filename: 2
# filename: concatWithingsSleepSensorResAttr.ipynb
# filename: dhcpattributes.csv
# filename: 1
# filename: 3
# filename: httpattributes.csv
# device_dir_path: SamsungCamera
# filename: 5
# filename: 4
# filename: 6
# filename: tlsattributes.csv
# filename: 10
# filename: 12
# filename: ssdpattributes.csv
# filename: 11
# filename: 9
# filename: dnsattributes.csv
# filename: 2
# filename: 7
# filename: dhcpattributes.csv
# filename: concatSamsungCameraResAttr.ipynb
# filename: 1
# filename: 8
# filename: 3
# filename: httpattributes.csv
# filename: ntpattributes.csv
# device_dir_path: WithingsBabyMonitor
# filename: rtmp-violations.csv
# filename: WithingsBabyMonitor_0024e41118a8.pcapng_flowResult.csv
# filename: dnsattributes.csv
# filename: rtmpattributes.csv
# filename: dns-violations.csv
# filename: dhcpattributes.csv
# filename: icmp-violations.csv
# filename: icmpattributes.csv
# filename: mdnsattributes.csv
# filename: httpattributes.csv
# filename: mdns-violations.csv
# filename: http-violations.csv
# filename: dhcp-violations.csv
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_16856/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)

# %%
# for i in data_device['LiFXBulb']['dhcp'].columns:
#     print(i)

# %%
'''
unique_attr_device =    
    {
        device: {
            protocol: {
                attr_name: {
                    value_attr: number_of_ccurences,
                    ...
                }
                ...
                'unique_flows_using_attribute': [list of unique flows]
                'num_violated_flows': len(unique_flows_using_attribute)
            },
            ...
        } ,
        ...
    }
'''

# srcMac, dstMac, ethType, srcIp, dstIp, ipProto, srcPort, dstPort

unique_attr_device = {}
for device, protos in data_device.items():  # per device
    attr_name_str = ''
    print('device:', device)
    unique_attr_proto = {}
    for proto, df in protos.items():  # per protocol

        if proto == checkedProto:  # proto == 'tls':  # running only for a selected protocol ######################################################################
            print(f'\t{device} --> proto: {proto}')
            attr = {}
            # num_violated_flows = 0

            for col in df.columns[8:]:
                
                # if col == 'server-hello-certificates':  # TLS skipping a specific attribute ######################################################################
                #     continue
                # if 'uri' in col:  # HTTP skipping a specific attribute ######################################################################
                #     continue
                # if col == 'origin timestamp' or col == 'transmit timestamp' or col == 'reference id':  # NTP skipping a specific attribute ######################################################################
                    # continue
                # if col == 'transaction id':  # DNS skipping a specific attribute ######################################################################
                #     continue

                # checing only the transaction ID 
                if col != 'origin timestamp':  # DNS skipping a specific attribute ######################################################################
                    continue

                print(f'\t\t{device}:{proto} --> attr: {col}')
                unique_flows_using_attribute = []   
                # attr_name = col
                # attr_name_str = ''
                for index in df.index:  # per line in the df
                    # print('\t\t\tindex:', index)
                    value_attr = df[col][index]  ####
                    # if value_attr == ' ':
                    # print(f'{device}:{proto}:{col} --> {value_attr}')
                    # making a flow signature
                    # value_flow = df[' srcIp'][index] + '-' + df[' dstIp'][index] + '-' + str(df[' ipProto'][index]) + '-' + str(df[' srcPort'][index]) + '-' + str(df[' dstPort'][index])
                    
                    # if str(value_attr) not in attr_name_str:
                        # attr_name_list.append(value_attr)
                    attr_name_str = attr_name_str + '__' + str(value_attr)
                    # attr_name_dict[value_attr] += 1

                    # if value_flow not in unique_flows_using_attribute:  # adding unique flow with a violation
                    #     unique_flows_using_attribute.append(value_flow)  
                        # num_violated_flows += 1
                # attr_name_dict['unique_flows_using_attribute'] = []  # unique_flows_using_attribute  # commented out because not needed at this point, can uncomment to be used later
                # attr_name_dict['number_of_unique_flows'] = len(unique_flows_using_attribute)
                # attr[col] = attr_name_list

            # attr['number_of_unique_flows'] = len(unique_flows_using_attribute)
            
            # unique_attr_proto[proto] = attr_name_list
            # print(f'\t\t\tnumber of unique flows: ', len(unique_flows_using_attribute))

    # #####################################################################
    # df_to_save_temp = pd.DataFrame(unique_attr_proto)
    # # Specify the output CSV file path
    # output_file = '../../results/attributes/delete/'+device+'.csv'
    # # if os.path.exists(output_dir):
    # #     shutil.rmtree(output_dir)
    # # os.mkdir(output_dir)
    # # Write the DataFrame to the CSV file
    # df_to_save_temp.to_csv(df_to_save_temp, index=True, sep='|')
    # #####################################################################

    unique_attr_device[device] = attr_name_str

# with open('output2.json', 'w') as json_file:
#     json.dump(unique_viol_device, json_file)
# print(unique_attr_device)
# Out:
# device: AwairAirQuality
# 	AwairAirQuality --> proto: ntp
# 		AwairAirQuality:ntp --> attr: origin timestamp
# device: LiFXBulb
# 	LiFXBulb --> proto: ntp
# 		LiFXBulb:ntp --> attr: origin timestamp
# device: PixStarPhotoFrame
# device: RingDoorBell
# 	RingDoorBell --> proto: ntp
# 		RingDoorBell:ntp --> attr: origin timestamp
# device: TPLinkCamera
# 	TPLinkCamera --> proto: ntp
# 		TPLinkCamera:ntp --> attr: origin timestamp
# device: TribySpeaker
# 	TribySpeaker --> proto: ntp
# 		TribySpeaker:ntp --> attr: origin timestamp
# device: AmazonEcho
# 	AmazonEcho --> proto: ntp
# 		AmazonEcho:ntp --> attr: origin timestamp
# device: WithingsSleepSensor
# device: SamsungCamera
# 	SamsungCamera --> proto: ntp
# 		SamsungCamera:ntp --> attr: origin timestamp
# device: WithingsBabyMonitor

# %%
for k, v in unique_attr_device.items():
    print(f'key: {k}, value: {v}')
# Out:
# key: AwairAirQuality, value: __dbd5ba4300000000__dbd8796600000000__dbe71a8900000000__dbcf7c1900000000__dbdbe6eb00000000__dbec599600000000__dbd5c85800000000__dbe309e400000000__dbdb05ea00000000__dbdcabcc00000000__83aa7e8300000000__dc62228f00000000__dbe4e80700000000__dbeac1c400000000__dbe1b86300000000__dbe1feb300000000__dbd2deff00000000__dbcf51e900000000__dbe6fe6900000000__dbd67f2400000000__dbcfeb9e00000000__dbcfc16e00000000__dbe009e900000000__dbdaa37f00000000__dbe44d5600000000__dbe0f38200000000__dbe590c700000000__dbdd548d00000000__dbd2566100000000__dbd023de00000000__dbdb5a4a00000000__dbe8c06b00000000__dbee61e900000000__dbcfdd9300000000__dbdabf9a00000000__dbde9c4700000000__dbcff9ae00000000__dbe582b700000000__83aa7e8a00000000__dc62a12100000000__dbdf7d4800000000__dbe2531300000000__dbdb4c3a00000000__dbdc111b00000000__dbed64c800000000__dbdd1c4d00000000__dbd53bb200000000__dbe07a6900000000__dbcf8a2e00000000__dbcf27b900000000__dbecd82700000000__dbeb789500000000__dc63035000000000__dc623eb100000000__83aa7e8300000000__dbe4697600000000__dbe3eae500000000__dbe914cc00000000__dbe655a800000000__dbe9f3f100000000__dbcfcf7e00000000__dbe0422900000000__dbe0ad3200000000__dbdfedc900000000__dbeba2c500000000__dbe5204700000000__dbdbd8e000000000__dbe139d200000000__dbd9cae800000000__dbd0b07f00000000__83aa7e8300000000__dbd9aec800000000__dbd12f0f00000000__dbd21e2100000000__dbd007be00000000__dbd4d94200000000__dbe43f4600000000__dbe017f900000000__dbe744b900000000__dc62d92000000000__dbe8099a00000000__dbdab18a00000000__dbe5c90700000000__dbe4f61700000000__dbd4bd2200000000__dbe6e24900000000__dbdf0cc800000000__dbd1594000000000__dbcef48f00000000__dc6276f100000000__dbd6c57400000000__dbd4cb3200000000__dbe5669700000000__dbd45ab100000000__dbe9a16c00000000__dbe0c95200000000__dbdc3b4b00000000__dbe906bc00000000__dbe760da00000000__dbe817aa00000000__dbe60f5800000000__dbdeaa5700000000__dbd5d66300000000__dbe5588700000000__dbd19f9500000000__dc63116000000000__dbd492f200000000__dbd6630400000000__dbed9d0800000000__dbe7a72a00000000__dc6365c100000000__dbe1c67300000000__dbd93e4700000000__dbe2a77400000000__dbd2485100000000__dbdbaeab00000000__dbda578900000000__dbd69b4400000000__dbd0945f00000000__dbe8b25b00000000__dbdeb86700000000__dbd557d800000000__dbeb5c7500000000__dbcf10af00000000__dbdc495b00000000__dbd2728100000000__dbe736a900000000__dbe7d15a00000000__dbd2809100000000__dbcf35c900000000__dbe3c0b500000000__dbdd7ebd00000000__dbcf5ff900000000__dbe5d71800000000__dc68d2e500000000__dbe1721200000000__dc6230a100000000__83aa7ebb00000000__dbd2c6e200000000__dbea514400000000__83aa7e8300000000__dbe1d48300000000__dc62cb1000000000__dbd5037200000000__dbdfc39800000000__dbd2647100000000__dbd6b76400000000__dbdc2d3c00000000__dbd4e75200000000__dbdd9add00000000__dbe10fa200000000__dbde8e3700000000__dbcf029f00000000__dc625ad100000000__dbe5123700000000__dbcfa64a00000000__dbd85d4600000000__dbd05c1f00000000__dbcf43d900000000__dbd9222700000000__83aa7e8300000000__dbcf983900000000__dbe06c5900000000__dbd0a26f00000000__dbea979400000000__dbe493a600000000__dbd549c200000000__dbdfa77800000000__dbd22c3100000000__83aa7e8300000000__dbec4b8b00000000__dbda659900000000__dbcf6e0900000000__dbdda8ed00000000__dbe0887900000000__dbdf8b5800000000__dbe671c800000000__dc632d8100000000__83aa7ec900000000__dbcee67f00000000__dbdf36f800000000__dbdcb9dc00000000__dbd59e2300000000__dbe8a44b00000000__dbec4b8600000000__dbda956a00000000__dbdd2a5d00000000__dbe155f200000000__dbe9af7c00000000__dbe3887500000000
# key: LiFXBulb, value: __83d9516a00000000__83d923b600000000__83cf461500000000__83d160bc00000000__83cf66e000000000__83d881fe00000000__83caa62700000000__83cea90800000000__83ce7d5900000000__83c25eb200000000__83d0703500000000__83c0bb1c00000000__83d0f4a600000000__83bff2b900000000__83d52f3d00000000__83c861f600000000__83add83c00000000__83d7ed2b00000000__83ced2e500000000__83e6611800000000__83ce06fd00000000__83cd447600000000__83d41fdb00000000__83cdd94900000000__83d78be700000000__83b3610400000000__83d066d500000000__83cabfef00000000__83cf868300000000__83aceb8900000000__83d10a0500000000__83cf6c6100000000__83ddd73700000000__83e194f600000000__83b7b0ed00000000__83cd4a5200000000__83c391aa00000000__83b087d900000000__83c8a5ee00000000__83dc409400000000__83bd0f4d00000000__83ca1d0c00000000__83d57ac000000000__83e9c0bd00000000__83b8c0c700000000__83c0659700000000__83e8531d00000000__83e937a100000000__83db45cc00000000__83d03dd100000000__83d61bf000000000__83cfdf3900000000__83d740e700000000__83c5e5a300000000__83d57c9000000000__83ea31a100000000__83da218b00000000__83cb24b700000000__83bbc98b00000000__83cb8aab00000000__83d3d6b100000000__83df21b300000000__83b67b8900000000__83d37b4900000000__83ca911000000000__83adb06300000000__83d66ccb00000000__83c1ff8f00000000__83c1aa3200000000__83ebbee400000000__83ccb7db00000000__83ca29f000000000__83cc6baa00000000__83d8996e00000000__83ad3a0800000000__83cf287000000000__83d3210e00000000__83d0cf2100000000__83b00ba100000000__83c169be00000000__83ce558100000000__83d1c66400000000__83ceb13c00000000__83cf5ad400000000__83cc569200000000__83d76ea000000000__83ca80a800000000__83ce9c2400000000__83dc18bc00000000__83cb571b00000000__83d812aa00000000__83cfeb4b00000000__83bc01c500000000__83cab7bb00000000__83d0fcda00000000__83ccb6aa00000000__83cf6d9400000000__83b19cac00000000__83d2d0bf00000000__83ca3cb000000000__83d8e8a900000000__83ca610400000000__83ba573600000000__83cf711100000000__83e4d4fc00000000__83d6aae700000000__83e466d400000000__83b0743100000000__83ba15cb00000000__83e64e5300000000__83d956d000000000__83dc140c00000000__83d06f5c00000000__83d2b57900000000__83cd750700000000__83c5d08b00000000__83b09add00000000__83b3d63300000000__83d4029600000000__83cdb04500000000__83d4976900000000__83d883e000000000__83d54c8400000000__83cb2e1700000000__83ca774800000000__83acd9ef00000000__83ab40b100000000__83af3c7f00000000__83b6d24000000000__83dded7b00000000__83ca21bc00000000__83ced41100000000__83cbd63100000000__83db563400000000__83e8544a00000000__83dbe52c00000000__83ca716c00000000__83cb4c8f00000000__83de155700000000__83d7f43200000000__83deb4b200000000__83af195200000000__83d9b6e800000000__83dafa5800000000__83bdb93900000000__83d1c79000000000__83d17a3900000000__83d735e600000000__83cd982f00000000__83cfbc1800000000__83d7d81300000000__83d8081f00000000__83e90b1900000000__83cb80a400000000__83ca680c00000000__83df046700000000__83d8f02600000000__83cba0ef00000000__83cf7dfc00000000__83d4e4c100000000__83ea821800000000__83b1a4e600000000__83d569d000000000__83c0471f00000000__83d8bb6a00000000__83dc5b8800000000__83dce42e00000000__83cef73900000000__83d6dfa300000000__83d4f24800000000__83aac34d00000000__83ca3a5800000000__83cbf9ff00000000__83ca22e700000000__83d34d9500000000__83afa39a00000000__83e50ae400000000__83e251a700000000__83dbc7e000000000__83cf3cb500000000__83ce451900000000__83cd8e4f00000000__83d429e500000000__83bff06700000000__83cfbff000000000__83ca428c00000000__83db9f9200000000__83b226fa00000000__83cdab9500000000__83cbc41700000000__83d2831000000000__83dd4bc300000000__83ea501900000000__83dd658b00000000__83de0d1f00000000__83b9b48700000000__83aef9ae00000000__83d074e500000000__83e1179200000000__83e776ce00000000__83cc4f8a00000000__83ca335000000000__83cff65600000000__83d2027900000000__83d4127500000000__83d0046500000000__83cc79ba00000000__83dc108800000000__83ca15e500000000__83ca30f800000000__83cadae300000000__83cb99e700000000__83dc9f7f00000000__83b662ee00000000__83d381ad00000000__83cacba700000000__83c5105c00000000__83caa04b00000000__83ea5ef000000000__83ca267100000000__83b71d4100000000 ...
# key: PixStarPhotoFrame, value:
# key: RingDoorBell, value: __0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0__0
# key: TPLinkCamera, value: __dc74408b5da21e9f__dc7d801543cefaa1__dc97ecc068237474__dc635f08b8d045f6__dc841b3e71a9eb1b__dc72ee5bdaee6316__dc7c2de140d466f2__dc93f60b07f76a2e__db9de95818f4a557__dc6626c47eaee1fa__dc86bfbbadf47f91__dc8c08878250a457__dc7592d8cc117f7b__dc92a3c627ee4e25__dc7adbae980f01f5__dc78373998ed6fd4__dc856d7044c62e4a__dc82c8ef83669483__dc76e50949348b1e__dc993ef1036eb4e9__dc8d5aba1e273928__dc68cb3809cbee80__d78fcbddc3ef6b54__db9b44c1ebe72965__dc79897d2c33a470__d78e13007f92295d__dc8176c08335b0b6__dc8964247098c3ab__dc8eaced1f09fa53__dc95483b0247778d__db99f291ba0b3d43__dc64d49458a3725c__db9c970bf374eeb5__dc969a6a5d8904f2__d78e1304de785b52__dc8fff4abdc1d6c7__dc7ed259f5c347de__dc6778f465d49513__dc91517ccfd848f9__dc8811ebc0cab3e5__dc80248d5f3d3a19
# key: TribySpeaker, value: __db9b389062b59ff4__db9ddcd013f442c7__db9b38902f828750__db9e863836fb0652__83aa7f27e835569b__dbe006cd7079ed49__db9d33d3a0713971__dba26c7755032c2b__dba5b911bb80ae0b__dba9ae641ee55aab__dbe7491cbac379e7__dc3068c908c23048__dba4677c44cc761c__dbe7491c879054b2__dc3068c8a25e790b__dbc78c729c3c4374__dbc986b85c9badc5__dbe7491934f573f1__dc7857394a0b59f6__83b11860dad20625__dc41282117f10d62__dba9ae72a4a125c3__db993da54bac439d__dc7e4782b4029835__dba5b911884f4d1e__dba1c3b1d709f8d2__db99e6b47168dcf0__db9a8fa68e6d00b4__dbb405c8482e3986__db9b388ffc50a45d__dbca2f7d5c50eb88__dc3fd61451e976bc__dbaf66689f05e6a3__dba70aef48fe5161__83aa7f27b502c4e3__db9b389362666234__dbd61e9adff110e0__dbb20a88c49e8494__dc370a4eadb8c6a3__dbeb3272977e75bc__dbd61e9b4658276f__db99e6b50affb103__dba1c3b20a3cff46__dc31bb31de204c59__db99e6b4a498a222__db9fd7fbbbac439d__dbbfa3605116c1a2__dbaebd82df1a601f__dbaa5753c707a3f0__dbc986b7c303f19e__dba9ae63ebb431a8__dbea89707e8cebe9__dba26caa38954dde__db99e6b4d7cc0a78__dc2e6e032b2c258d__db9be15c9328ee0f__dc2b21003fafa1e1__db9a8fa7803992c8__dc31123311395c42__dbc986b8296887d8__dbea89704b5b4aa9__db9ddccfad8fecdd__dc63cb1c358b48bc__dc2b20e24a20c2dc__dbd575dbca41280a__dba26c778833fa4f__dbca2f7dc2b6c4bc__dbdf5e05794f33f4__db9a8fa6f4d10856__db9f2efa9f616f86__dc7857449c17bcd7__dbd575db30a8c582__db9a8fa6c19dc7da__db993da5b21197fe__dbe7491c545cd332__dc7afb10a64d3e0b__dbc986b7f6357419__dba26caa67d844b2__dbeb3272caaf05a7__83b11860746c93b3__db9c8a9452450a13__dbaebd9bb1d18b0d__dc63cb1c699dafa4__dbcbd3b02d5ebab5__dbd4cc658a31ceaf__dc3068c93bf5cfd4__dc2e6e071de1874c__dc63caf358ccaaca__dbca2f7d8f83d6be__dbeb327231178f68__dba11aebdb165328__dbb161230e9d2391__dba5b91221e6ba49__dbc2ef29be11f825__dbc8ddf497d31112__dbb161239aebe379__83b11860a79c2ac3__dbd61e9aacbf3a81__dbcfca72df3d1c0c__dc2dc4fd20e3aaa3__dbcf20c51ec3d3b6__dba1c3b1a3d63eb2__83b118604136b0a3__dba5b911eeb3a472__dba1c3b170a5f4b1__dbeb327264492092__dbb161240152ab0c__dc75915d603ca482__dbd575db97136128__dc78573916d78062__db993da57ede25dd
# key: AmazonEcho, value: __6a4fe187d3908704__48bfe1a62aff894e__5a3f3b7ecf4ab249__f7e7eb92abc74d1c__12e97575651cefd4__94c108f78fa8e261__22e94cec582af7bd__2bf6792654acc9c7__d13e0cedde088891__82570697f003dedb__dbd44d968c0774db__2cc7c60bbf77aae5__f9b40367ea66bdb0__9c82fcaaf50e3f24__f1d849bcce6a75ef__ec3dfc085a548315__4af48d70e4358dc5__a9e4d0bb89d8c795__38693020208ba662__1c3ab4742ee3365b__ee9bfb9accd83b2c__bd9bb3b8e4545365__19b36789b0e24653__dd6cb31a31628f7b__4e1deb6c606f53d6__8e7cc07cd21cc8b7__e4bcf1a108dd4aef__afa2c28fddd2915d__192b43a0c76edbc4__cfc6adbcaf5145ec__98df60a9459a6b1c__e763939663f7babd__60f26ec2580998af__dddba4a4a0532e44__748d935de3fce9cd__98f0a77770712ab0__becf65aa9020ef20__9d2082fc2e30c3a1__2591449642eba556__ff83315348ddf333__8fd446a9d4c8208e__490c04c5c4ba2400__bfa118f9744f1efa__6f38d07538d25f73__d743b24f4c1aa1eb__54a81d6c25fde3f4__b73b8719bc128bb1__e91ea3568ddf111b__de12df6abd9abd7d__29cb7027f941023e__6b43f277000cb63c__aaa9d6279a780c65__563ce94c2053ef63__81f4846975fa7c28__df469f4a37dc1aab__a1b103d51892b43b__46d3bf32b5b3ac74__10f6533a66effe48__4c52d46c7900e739__54499dfe1630545f__08b02a53cf199238__73fae017c6ec5755__3565b10fcfb8b436__6c8122bd1b7621eb__ff91ebe2561bb022__52f15f63672e8a49__b7cd06a7ab30bbef__1a55bf98d2a3ad39__98a046bd708ce2cc__0d0e1ea3007e4785__0722e4ddf3e64444__bcdc7b68bf413ba1__a96e7604c3d12a2a__45e6e7b5d8a099fc__0027845612d244aa__eae5b23ef1bbe4b5__476c04498a3f4d45__fe6e7891ebee075b__0897db54ad41ed79__70e514359e41440f__26997923ef2ea21d__99c5013e94a4fe1a__d26100b99f2b2f5c__5c45951c0065f508__ee1b4df8d0bdcd03__c532ce77341c24ca__c117d8608c86a890__b56710f109ff0fcf__f580aecb3e28a212__433ccb4d178a8768__1dea9ca3b8278fb4__40d81093eb104fe4__3f0e4e670f92240b__2980ff4251429f4e__aa6a5dd3164aea29__554b8956f94cf74f__99154f18c7c57b06__3e3e896ad9ae0ee8__96ac45397778c4cb__203ae149e1f6591a__f315d5e0dbeeac9c__401095ef8abb38c3__213a129b2e6a442f__2fcecf4abb961648__675883a3ddfda057__d1d2f3e501750018__7e7554facc0e49b3__6229264214f51925__7d89cf274f1ea298__25a321146443fd87__b45770b351e52444__bb0d599621f27580__0d2ed65350d86e43__6a1fc3c83e68be15__c2a615b56c7cb385__613cafa3094cf5cd__53cb12921baf6589__179758a95bfa2673__0be0b5b8d2a78085__2ee81ebad9b0b8b5__d3048ce72006a11c__2ba5b975a26f2f65__7d5a4a424dfedace__b1f889ae305ec6cf__c33ea3e18fd314c9__3e66e3222de450bc__f95cb87f8a61a1d8__84740814a6355e1b__786721ad4c343a41__4c37cb7217368993__4bf4b216417f27ef__83c49f8deb5d688f__778d46bc4b49e6b0__711a70df1e6e5a8b__aa19c2440759a429__1dd05d952d853c0f__dde3fb190f39dd8a__86ea25bf2f2de98c__a522948cc1e6f221__6c137498e575bf1e__26f522d3ef5fbd9c__f4bb6a12c4f50c22__f14891c2ebf7d35c__1454a6fe0b24b223__f5dc401f2b8036d9__ee983fcd10621d3c__6339b7d6ee0f2fd9__33bc98f4a11af9cd__096acf72181de873__7a69fab3d38ddf4e__80365deb6af1be11__d36afa9ba756a3ba__95b0565c8956c4cc__54f70a043101db65__1b26243a1ac35392__4f33800000f5e87e__2b759d2c1c1459f2__28e52f5765e53480__8173384e75861ba9__948b8b5fc6603d43__4b9303f2120543c6__d92f67bf88cf89b6__86015275006c9237__ddf335cd0481c737__cde057d040106d25__1a4cc0f1108e7810__4a43c37897b35367__463dce6b6c4f9de2__c623551a21912994__ca9760612c97e5f5__219293ed91a5a132__f6739f3ff351124e__674da846012e69b9__24bbc2b7176e39ce__83c1c271811b2bdb__a8d5a87480c2df47__c0e137b027ef6bbf__56ae81be84c367f8__2c9b555bf47c6555__f39388f93d9a14b9__7c5ccf4d5cf31aba__710b077492378517__80f40ade4a39d8dc__20f5b9404ad6fa92__8b90bcebb1c93d3b__13241bfcbebc8faf__d4b8c2afa6b874a8__b4e9ea99e29458df__30e039fb4b127494__8e82676765ad5531__56c02a935e2036a8__b14a584368db4562__f7d2a2230868e5e1__64c75ab3513f2c40__2885dcfbdce1e4df__68fd46dfd781c592__af6664769ae401bf__36a14668f274f4bb__ad1f0261219c6f40__983f830a66f04102__5ee315c515fb77a7__050e8191051fb6ec__6ea2ec03dbeae8c8__83630a09f9ec4113__c1443bcbb21159c9__f8146e9a53ddde15__7cddb7a5593c1394__5b89a9dbe07ceda4__61484357e4e04073__927163df730574e1__b7376b9343081020__f6fbe0c9436670de__72e94cda05eef0cb__abaaef1439a91077__b1b7d2fcf132066a__2475edb2ccb24e36__2013c051431911df__9eb08c39671ab3cb__e0d9c95cb46af8de__03c6903c16a43c7f__24b693e29c5194 ...
# key: WithingsSleepSensor, value:
# key: SamsungCamera, value: __dba219a8161b2a27__dba2c26990384ba0__db9b4450153a0c6b__db9a472e538aa001__db9cd38baf3e468c__db999e67f599aa60__db9f222efdb25f63__db9ecdce9cd64d7f__dba01f56132f5558__db9dd0ad6282517e__db9e250dc6903643__db994a0714e1e710__dba26e0923939a7c__db9c7f2afc332f01__db9d7c4c8fa1c25d__db9b98b08abf0132__db9f768fb45d52c1__db9c4171ce84be40__dba1c542b2c32229__db9d27ec1de6cd29__db9aefefacbb7f9d__dba0c81c04df15a4__db98f5a115f59ccf__dba11c81bd25edd0__dba316c9f7dd334c__db9fcaf55ef4e011__db9a9b8eb9c45458__db9e796e2826bb55__dba073b672cacd18__db9bed1167a50939__db99f2cdee244630__db999e6d5fb43d89__dba170e254eeae9e__dba4bcb71196a6a0__dbae695c3ea64c2f__dbacc594b73a7978__dba6b6fa26cfd8f0__dba80886ee8155d5__dba7b4212f56eac8__dbab0001a62c12ad__dbad6e5ae197d49d__dba70b5ff2ee5258__dbaa574079aac53b__dbaa02daaa2de870__dba46856a777c02a__dba5b9d84fa7fc32__dba6b6ff486dd69d__dbac71345404b7f5__dba75fc0662c98e5__dbaebdbca9bd2fa0__dba36b34fe586013__dbab741275ec0b56__dbaf667dbfeb074a__dba60e38f6a7264a__dba95a1423291b82__dba413f60dff2e48__dba905b35054ef45__dbaaaba1387b890d__dba51117738fabda__dbadc2bb46d9dfda__dbab1fb22ead1d04__dbabc87330dd1e53__dbad19fa2b545c78__dbaf121d24bc2763__dbac1cd396071c53__dba66299b00b1359__dba9ae7489749279__dba3bf9580a45d41__dba56577dd749279__dbb45825b78ad256__dbb7f8552f7ced91__dbb84cb5dae3b46f__dbba46ffb9e0c5a8__dbbbece268219eb6__dbbb442135fce315__dbb8a116494573a7__dbbc4142e858bc59__dbb3af64addbdb5d__dbb5fe0d4b2e8c04__dbafbade6ecc2d6a__dbb99e3e4b0f6ad7__dbb949ddac36eb4e__dbbc95a3d36b5d46__dbb403c53e77c45c__dbb6a6d32071e6cd__dbba9b602ad234eb__dbb74f9412358298__dbb160c0cd04a2fc__dbb8f576f5f42bb6__dbb7a3f4be7bf61a__dbb00f3eef78feef__dbb0639f78aefb2a__dbbd92caeb7f38c5__dbb25de28fb99d45__dbbaefc0c07c30d3__dbb500e6953a81dc__dbb2b2434256ffc1__dbb65272b7a3db3b__dbb35b041ffb3743__dbb9f29efc36b8f9__dbbcea0469c853c1__dbb6fb3390adab9f__dbbd3e6a539884c6__dbb4ac8631cd2d44__dbb0b7fff773affb__dbb1b52143566490__dbb5554702d14a0a__dbbde72b7a1bb05f__dbb209821c28b2a6__dbb306a3a32b239a__dbb5a9aceab862b2__dbb10c60610a2446__dbbb9881e51d68c6__dbca3d3577ceb788__dbc08a345dac258d__dbc7ca9e5ae1693c__dbbf38ad3cc1333b__dbc7763e0e0a2014__dbc81efeb4258d58__dbcc285460e3369b__dbbee44cc2e3a3a8__dbc6cd7761907d91__dbc381a81b457c0b__dbc8c7bf82e81882__dbc2d8e6d651c193__dbc0de9a15fe004b__dbcc7cb4cfcec84f__dbc9e8d52ca31e7d__dbc42a6981c66d37__dbcb7f93857be985__dbc1dbc09ca1be2b__dbc721dd607fdc59__dbc5d05103d2fa0d__dbc91c1ff9b317ef__dbcb2b330f9713ad__dbc132fa9487db2b__dbbfe16e5118b0d0__dbc32d478d314445__dbbe8fec508abd5d__dbcad6d2a6f46aa0__dbbe3b8beb0153bd__dbc3d60907f0995a__dbc67916e34a2339__dbc9c4e0e6cffa7e__dbc8735f2280e065__dbccd1153d1cb039__dbc624b17e795703__dbcbd3f3f32f9873__dbc230211547064e__dbc97080774a771c__dbbf8d0dd8180d3c__dbc035cec0a3d70a__dbc1875afc536d65__dbc284866fc7607c__dbdc77210a527a20__dbcd257b0856e696__dbd2bfe97133c1ce__dbd4cbafb9dabe27__dbd6884cc46088d6__dbdb25939fb4d488__dbd57280b615336d__dbdc22badbdfa00e__dbd97fb1298372e6__dbdbce59afa7daa4__dbd4774ef815a07b__dbd633ec70b923a2__dbd217285e4e26d4__dbcfc8847e1b7e0a__dbd8d6f0698793dd__dbd01ce4f1460aa6__dbd92b50c24a59c0__dbd16e673ba1e3ea__dbdd1fe261dfdac6__dbd5c6e18a744b2b__dbd26b88fa5b63d3__dbce229cf1c36976__dbdb79f428f4f93b__dbd61b4210886162__dbcd79dbd93c579f__dbcdce3c5c848387__dbd51e20513fd0d0__dbd07145b1826677__dbcf7423fb530ced__dbdad1330add9c27__dbd11a06bfac710c__dbda287225ccb7d4__dbdccb81db1e0828__dbda7cd2964851a8__dbd88290053f5b5f__dbcd2575ec12cf0f__dbd9d411a4cc2507__dbd1c2c7a45ff1d8__dbce76fd9371da37__dbdc771b9edc7ef1__dbd82e2f0f7318fc__dbcf1fbe8757d5a9__dbd0c5a6319ba1b1__dbcecb5e0d40bbb1__dbe6273487939a7c__dbe3d8911162f166__dbe08cc2334efcbd__dbdd7447cc0e27e0__dbe2db6a8daad601__dbe6cff585490e66__dbde927f0af3c2da__dbdf8fa05c3c07ee__dbe5d2d40bc158fb__dbe4815208940bbb__dbe03861742d16b9__dbde1d08e15e17e3__dbe287051fa58f71__dbe232a4ab9dd3ba__dbe52a13019029ae__dbe778b673079e59__dbddc8a843fdc593__dbe384308815a07b__dbe1358367daf8df__dbdf3b3ff71886df__dbdfe400fe2a6f3f__dbe724560059b802__dbe32fd00e1 ...
# key: WithingsBabyMonitor, value:

# %%
# df_to_save = pd.DataFrame(unique_attr_device)
# df_to_save['TPLinkCamera']['classic-stun']

# %%
df_to_save = pd.DataFrame(unique_attr_device.items(), columns=["Device", "TransID"])
df_to_save.head()


# Specify the output CSV file path
# final_output_file = '../../results/attributes/v1_request_attributes.csv'  # define in the beginning

# Write the DataFrame to the CSV file
df_to_save.to_csv(final_output_file, index=False, sep='|')

df_to_save.head()
# Out:
#               Device                                            TransID
# 0    AwairAirQuality  __dbd5ba4300000000__dbd8796600000000__dbe71a89...
# 1           LiFXBulb  __83d9516a00000000__83d923b600000000__83cf4615...
# 2  PixStarPhotoFrame
# 3       RingDoorBell  __0__0__0__0__0__0__0__0__0__0__0__0__0__0__0_...
# 4       TPLinkCamera  __dc74408b5da21e9f__dc7d801543cefaa1__dc97ecc0...
