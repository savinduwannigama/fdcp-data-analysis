# %%
# importing pandas as pd
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
import shutil

# %%
device_dir_paths = [
    'AwairAirQuality',
    'LiFXBulb',
    'PixStarPhotoFrame',
    'RingDoorBell',
    'TPLinkCamera',
    # 'TribySpeaker',

    # 'AmazonEcho/1',
    # 'AmazonEcho/2',
    # 'AmazonEcho/3',
    # 'AmazonEcho/4',
    # 'AmazonEcho/5',
    # 'AmazonEcho/6',
    # 'AmazonEcho/7',
    # 'AmazonEcho/8',
    # 'AmazonEcho/9',
    # 'AmazonEcho',

    # 'NestProtect/1',
    # 'NestProtect/2',
    # 'NestProtect/3',
    # 'NestProtect/4',
    # 'NestProtect/5',
    # 'NestProtect/6',
    # 'NestProtect/7',

    # 'WithingsSleepSensor/1',
    # 'WithingsSleepSensor/2',
    # 'WithingsSleepSensor/3',
    # 'WithingsSleepSensor/4',
    # 'WithingsSleepSensor',

    # 'SamsungCamera/1',
    # 'SamsungCamera/2',
    # 'SamsungCamera/3',
    # 'SamsungCamera/4',
    # 'SamsungCamera/5',
    # 'SamsungCamera/6',
    # 'SamsungCamera/7',
    # 'SamsungCamera/8',
    # 'SamsungCamera/9',
    # 'SamsungCamera/10',
    # 'SamsungCamera/11',
    # 'SamsungCamera/12',
    # 'SamsungCamera',

    # 'WithingsBabyMonitor'
]

# %%
# for RESPONSE attribute files
root_dir_path = '../../../data/attributes/V3/request_dns_domain_names'
final_output_file = '../../../results/attributes/DNS/NEW_dns_domain_name_response_attributes.csv'

##################################################################################

# for REQUEST attribute files
# root_dir_path = '../../../data/attributes/V3/request_attributes'
# final_output_file = '../../../results/attributes/DNS/NEW_dns_transID_request_attributes.csv'  

checkedProto = 'dns'

# %%
'''
data_device =    
    {
        device: {
            protocol: df of attributes.csv
            ...
        } ,
        ...
    }
'''

# Create an empty list to store the data from CSV files
data_device = {}

for device_dir_path in device_dir_paths:
    # this is needed because for outputs from the java script the separator is ',,,'.
    # but for devices with concatanated attribute files the separator is '/'
    if device_dir_path == 'SamsungCamera' or device_dir_path == 'AmazonEcho' or device_dir_path == 'WithingsSleepSensor':
        sepa = '|'
    else:
        sepa = ',,,'
    data_proto = {}
    print(f'device_dir_path: {device_dir_path}')
    directory_path  = os.path.join(root_dir_path, device_dir_path)
    # print(f'directory_path: {directory_path}')
    # Get a list of all files in the directory
    file_list = os.listdir(directory_path)

    # Iterate over each file in the directory
    for file_name in file_list:
        print(f'filename: {file_name}')
        # reading only the attributes files
        if 'attributes' in file_name:
            proto = file_name.split('attributes')[0]
            # Check if the file is a CSV file
            if file_name.endswith('.csv'):
                # Create the file path
                file_path = os.path.join(directory_path, file_name)
                # print(f'device_dir_path: {device_dir_path}  |  proto: {proto}')
                # Read the CSV file and append its data to the list
                try:
                    df = pd.read_csv(file_path, sep=sepa)
                    # df = pd.read_csv(file_path, sep='|')
                except pd.errors.EmptyDataError:
                    df = pd.DataFrame()  # Create an empty DataFrame 

                # data.append(df)

                data_proto[proto] = df
                # data_proto[proto] = 'df'
    
    data_device[device_dir_path] = data_proto

# # Write dictionary as JSON
# with open('output.json', 'w') as json_file:
#     json.dump(data_device, json_file)

# data_device['AwairAirQuality']['tls'][' violations']
# Out:
# device_dir_path: AwairAirQuality
# filename: dnsattributes.csv
# device_dir_path: LiFXBulb
# filename: dnsattributes.csv
# device_dir_path: PixStarPhotoFrame
# filename: dnsattributes.csv
# device_dir_path: RingDoorBell
# filename: dnsattributes.csv
# device_dir_path: TPLinkCamera
# filename: dnsattributes.csv
# /tmp/ipykernel_9807/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_9807/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_9807/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_9807/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)
# /tmp/ipykernel_9807/3426504225.py:42: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, sep=sepa)

# %%
# for i in data_device['LiFXBulb']['dhcp'].columns:
#     print(i)

# %%
'''
unique_attr_device =    
    {
        device: {
            protocol: {
                attr_name: {
                    value_attr: number_of_ccurences,
                    ...
                }
                ...
                'unique_flows_using_attribute': [list of unique flows]
                'num_violated_flows': len(unique_flows_using_attribute)
            },
            ...
        } ,
        ...
    }
'''

# srcMac, dstMac, ethType, srcIp, dstIp, ipProto, srcPort, dstPort

unique_attr_device = {}
for device, protos in data_device.items():  # per device
    attr_name_str = ''
    print('device:', device)
    unique_attr_proto = {}
    for proto, df in protos.items():  # per protocol

        if proto == checkedProto:  # proto == 'tls':  # running only for a selected protocol ######################################################################
            print(f'\t{device} --> proto: {proto}')
            attr = {}
            # num_violated_flows = 0

            print(f'df.columns: {df.columns}')
            for col in df.columns[8:]:
                
                # if col == 'server-hello-certificates':  # TLS skipping a specific attribute ######################################################################
                #     continue
                # if 'uri' in col:  # HTTP skipping a specific attribute ######################################################################
                #     continue
                # if col == 'origin timestamp' or col == 'transmit timestamp' or col == 'reference id':  # NTP skipping a specific attribute ######################################################################
                    # continue
                # if col == 'transaction id':  # DNS skipping a specific attribute ######################################################################
                #     continue

                # checing only the transaction ID 
                if 'domain name' not in col:  # DHCP skipping a specific attribute ######################################################################
                    continue

                print(f'\t\t{device}:{proto} --> attr: {col}')
                unique_flows_using_attribute = []   
                # attr_name = col
                # attr_name_str = ''
                for index in df.index:  # per line in the df
                    # print('\t\t\tindex:', index)
                    value_attr = df[col][index].split(',,')[0]  ####
                    # if value_attr == ' ':
                    # print(f'{device}:{proto}:{col} --> {value_attr}')
                    # making a flow signature
                    # value_flow = df[' srcIp'][index] + '-' + df[' dstIp'][index] + '-' + str(df[' ipProto'][index]) + '-' + str(df[' srcPort'][index]) + '-' + str(df[' dstPort'][index])
                    
                    if str(value_attr) not in attr_name_str:
                        # attr_name_list.append(value_attr)
                        attr_name_str = attr_name_str + '__' + str(value_attr)
                    # attr_name_dict[value_attr] += 1

                    # if value_flow not in unique_flows_using_attribute:  # adding unique flow with a violation
                    #     unique_flows_using_attribute.append(value_flow)  
                        # num_violated_flows += 1
                # attr_name_dict['unique_flows_using_attribute'] = []  # unique_flows_using_attribute  # commented out because not needed at this point, can uncomment to be used later
                # attr_name_dict['number_of_unique_flows'] = len(unique_flows_using_attribute)
                # attr[col] = attr_name_list

            # attr['number_of_unique_flows'] = len(unique_flows_using_attribute)
            
            # unique_attr_proto[proto] = attr_name_list
            print(f'\t\t\tnumber of unique flows: ', len(unique_flows_using_attribute))

    # #####################################################################
    # df_to_save_temp = pd.DataFrame(unique_attr_proto)
    # # Specify the output CSV file path
    # output_file = '../../results/attributes/delete/'+device+'.csv'
    # # if os.path.exists(output_dir):
    # #     shutil.rmtree(output_dir)
    # # os.mkdir(output_dir)
    # # Write the DataFrame to the CSV file
    # df_to_save_temp.to_csv(df_to_save_temp, index=True, sep='|')
    # #####################################################################

    unique_attr_device[device] = attr_name_str

# with open('output2.json', 'w') as json_file:
#     json.dump(unique_viol_device, json_file)
# print(unique_attr_device)
# Out:
# device: AwairAirQuality
# 	AwairAirQuality --> proto: dns
# df.columns: Index(['srcMac', ' dstMac', ' ethType', ' srcIp', ' dstIp', ' ipProto',
#        ' srcPort', ' dstPort', 'transaction id', 'flags', 'Qnumber',
#        'domain name,,'],
#       dtype='object')
# 		AwairAirQuality:dns --> attr: domain name,,
# 			number of unique flows:  0
# device: LiFXBulb
# 	LiFXBulb --> proto: dns
# df.columns: Index(['srcMac', ' dstMac', ' ethType', ' srcIp', ' dstIp', ' ipProto',
#        ' srcPort', ' dstPort', 'transaction id', 'flags', 'Qnumber',
#        'domain name,,'],
#       dtype='object')
# 		LiFXBulb:dns --> attr: domain name,,
# 			number of unique flows:  0
# device: PixStarPhotoFrame
# 	PixStarPhotoFrame --> proto: dns
# df.columns: Index(['srcMac', ' dstMac', ' ethType', ' srcIp', ' dstIp', ' ipProto',
#        ' srcPort', ' dstPort', 'transaction id', 'flags', 'Qnumber',
#        'domain name,,'],
#       dtype='object')
# 		PixStarPhotoFrame:dns --> attr: domain name,,
# 			number of unique flows:  0
# device: RingDoorBell
# 	RingDoorBell --> proto: dns
# df.columns: Index(['srcMac', ' dstMac', ' ethType', ' srcIp', ' dstIp', ' ipProto',
#        ' srcPort', ' dstPort', 'transaction id', 'flags', 'Qnumber',
#        'domain name,,'],
#       dtype='object')
# 		RingDoorBell:dns --> attr: domain name,,
# 			number of unique flows:  0
# device: TPLinkCamera
# 	TPLinkCamera --> proto: dns
# df.columns: Index(['srcMac', ' dstMac', ' ethType', ' srcIp', ' dstIp', ' ipProto',
#        ' srcPort', ' dstPort', 'transaction id', 'flags', 'Qnumber',
#        'domain name,,'],
#       dtype='object')
# 		TPLinkCamera:dns --> attr: domain name,,
# 			number of unique flows:  0

# %%
for k, v in unique_attr_device.items():
    print(f'key: {k}, value: {v}')
# Out:
# key: AwairAirQuality, value: __04706f6f6c036e7470036f726700000100010000__0a74696d65736572766572056177616972026973__036f746105617761697202697300000100010000__096d6573736167696e6705617761697202697300__0361706905617761697202697300000100010000
# key: LiFXBulb, value: __04706f6f6c036e7470036f726700000100010000__0276320662726f6b6572046c69667802636f0000
# key: PixStarPhotoFrame, value: __03617069087069782d7374617203636f6d00001c__03617069087069782d7374617203636f6d012300__03617069087069782d7374617203636f6d000001__0573756e36690123000001000100000000000000__03617069087069782d7374617203636f6d036c61__03617069087069782d7374617203636f6d05776c__0573756e3669036c616e00000100010000000000__06697074696d65087069782d7374617203636f6d__0573756e36690000010001000000000000000000__0573756e3669012300001c000100000000000000__0573756e366905776c616e300000010001000000__0573756e366900001c0001000000000000000000__0573756e366905776c616e3000001c0001000000__0573756e3669036c616e00001c00010000000000__0573756e366905776c616e3000001c0001af5501__0573756e366901230000010001698d0100000100__204641454a4649434e4644464545424643434e44__0573756e366900001c00013cae01000001000000__0573756e3669012300000100019bb80100000100
# key: RingDoorBell, value: __0266770472696e6703636f6d00000100016b6101__0266770472696e6703636f6d0000010001000000__0266770472696e6703636f6d000001000119ed01__0266770472696e6703636f6d000001000180d801__0266770472696e6703636f6d000001000172c201__0266770472696e6703636f6d0000010001742001__0266770472696e6703636f6d000001000108b301__0266770472696e6703636f6d0000010001a6cb01__0266770472696e6703636f6d0000010001616d01__0266770472696e6703636f6d0000010001a88701__0266770472696e6703636f6d0000010001f4a601__0266770472696e6703636f6d000001000113b101__0266770472696e6703636f6d0000010001291c01__0266770472696e6703636f6d0000010001425801__013204706f6f6c036e7470036f72670000010001__0266770472696e6703636f6d0000010001be4201__0266770472696e6703636f6d000001000166eb01__0266770472696e6703636f6d00000100015eda01__0266770472696e6703636f6d0000010001b39001__0266770472696e6703636f6d00000100014c2501__0266770472696e6703636f6d0000010001133001__0266770472696e6703636f6d0000010001ce0101__0266770472696e6703636f6d0000010001365b01__0266770472696e6703636f6d000001000146c701__0266770472696e6703636f6d0000010001452c01__0266770472696e6703636f6d0000010001d2a101__0266770472696e6703636f6d0000010001320a01__0266770472696e6703636f6d0000010001165e01__0266770472696e6703636f6d00000100019e8501__0266770472696e6703636f6d00000100013cb801__0266770472696e6703636f6d0000010001f57201__0266770472696e6703636f6d0000010001ed1201__0266770472696e6703636f6d000001000148d701__0266770472696e6703636f6d00000100013e9f01__0266770472696e6703636f6d0000010001339801__0266770472696e6703636f6d0000010001d97901__0266770472696e6703636f6d00000100012d6c01__0266770472696e6703636f6d00000100012d6601__0266770472696e6703636f6d00000100018b8701__0266770472696e6703636f6d00000100010a0a01__0266770472696e6703636f6d0000010001738301__0266770472696e6703636f6d0000010001a12701__0266770472696e6703636f6d0000010001f76f01__0266770472696e6703636f6d0000010001652601__0266770472696e6703636f6d0000010001de8601__0266770472696e6703636f6d0000010001617301__0266770472696e6703636f6d000001000105ed01__0266770472696e6703636f6d0000010001359701__0266770472696e6703636f6d0000010001edc601__0266770472696e6703636f6d000001000198c701__0266770472696e6703636f6d0000010001389401__0266770472696e6703636f6d000001000167d701__0266770472696e6703636f6d0000010001d4c901__0266770472696e6703636f6d000001000185cb01__0266770472696e6703636f6d000001000103f301__0266770472696e6703636f6d0000010001309f01__0266770472696e6703636f6d0000010001ceb501__0266770472696e6703636f6d0000010001f0a201__0266770472696e6703636f6d0000010001fcc801__0266770472696e6703636f6d00000100011e9d01__0266770472696e6703636f6d00000100019ca801__0266770472696e6703636f6d0000010001ce4901__0270730472696e6703636f6d000001000144dc01__0266770472696e6703636f6d00000100014f3401__0266770472696e6703636f6d0000010001807c01__0266770472696e6703636f6d00000100014a8a01__0266770472696e6703636f6d0000010001b11301__0266770472696e6703636f6d0000010001aff701__0266770472696e6703636f6d0000010001366c01__0266770472696e6703636f6d0000010001b27501__0266770472696e6703636f6d00000100010c2201__0266770472696e6703636f6d00000100017cc701__0266770472696e6703636f6d0000010001ce5101__0266770472696e6703636f6d0000010001e15801__0266770472696e6703636f6d000001000167c701__0266770472696e6703636f6d0000010001f86701__0266770472696e6703636f6d0000010001db3001__0266770472696e6703636f6d00000100014a7401__0266770472696e6703636f6d000001000199eb01__0266770472696e6703636f6d000001000132d601__0266770472696e6703636f6d0000010001251101__0266770472696e6703636f6d0000010001a40501__0266770472696e6703636f6d0000010001ecc401__0266770472696e6703636f6d0000010001afc801__0266770472696e6703636f6d0000010001ff5301__0266770472696e6703636f6d00000100013a3c01__0266770472696e6703636f6d0000010001a7c601__0266770472696e6703636f6d0000010001d58001__0266770472696e6703636f6d0000010001da7701__0266770472696e6703636f6d0000010001e59101__0266770472696e6703636f6d0000010001073b01__0266770472696e6703636f6d0000010001b40a01__0266770472696e6703636f6d0000010001ce7e01__0266770472696e6703636f6d00000100013f9901__0266770472696e6703636f6d ...
# key: TPLinkCamera, value: __0a617073312d72656c61790b74706c696e6b636c__0773672d7374756e0b74706c696e6b636c6f7564__04646576730b74706c696e6b636c6f756403636f__013004706f6f6c036e7470036f72670000010001__036970630b74706c696e6b636c6f756403636f6d

# %%
# df_to_save = pd.DataFrame(unique_attr_device)
# df_to_save['TPLinkCamera']['classic-stun']

# %%
df_to_save = pd.DataFrame(unique_attr_device.items(), columns=["Device", "TransID"])
df_to_save.head()


# Specify the output CSV file path
# final_output_file = '../../results/attributes/v1_request_attributes.csv'  # define in the beginning

# Write the DataFrame to the CSV file
df_to_save.to_csv(final_output_file, index=False, sep='|')

df_to_save.head()
# Out:
#               Device                                            TransID
# 0    AwairAirQuality  __04706f6f6c036e7470036f726700000100010000__0a...
# 1           LiFXBulb  __04706f6f6c036e7470036f726700000100010000__02...
# 2  PixStarPhotoFrame  __03617069087069782d7374617203636f6d00001c__03...
# 3       RingDoorBell  __0266770472696e6703636f6d00000100016b6101__02...
# 4       TPLinkCamera  __0a617073312d72656c61790b74706c696e6b636c__07...
